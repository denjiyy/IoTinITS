# %% [markdown]
# # Tabular ML Demo: Multi-Hour Travel Time Regression
#
# Този notebook описва втория ML модел в проекта: `RandomForestRegressor` върху `sofia_route_network.csv`.

# %% [markdown]
# ## Dataset
#
# - Файл: `../sofia_route_network.csv`
# - Тип: tabular dataset
# - Използвани feature-и: speed, lanes, congestion fields, traffic profiles, green profiles, road class, direction
# - Таргет: `travel_time_min` за multi-hour сценарий (`hour=0..23`)
#
# ## Модел
#
# - `RandomForestRegressor`
# - Обучение върху репрезентативна извадка от dataset-а
#
# ## Резултат
#
# - MAE: 0.0041 min
# - RMSE: 0.0139 min
# - R²: 0.9797

# %%
import json
from pathlib import Path

results = json.loads(Path('travel_time_random_forest_results.json').read_text(encoding='utf-8'))
results['metrics']

# %%
print('To retrain the model run: python3 ml_demo/train_travel_time_random_forest.py')
